# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\Datasets\Luminar\Advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x=df['TV'],y=y,color='red')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='red')
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['Newspaper'],y=y,color='red')
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21.17093703, 24.84608677, 13.78194093,  6.33359731, 11.86978977,
#        11.75202961, 15.52111852, 18.29807422,  9.85236642, 16.58167411,
#        13.33769405,  9.16469257, 15.25775425, 18.57796019, 17.9502047 ,
#        21.98721776,  8.00134405,  8.35652188, 14.56932611,  8.31909419,
#        23.91716704, 14.50092457, 24.52313266, 13.73372083,  8.21301193,
#        12.21047103,  9.43825054,  7.15178563, 19.275088  , 11.47241051,
#        19.14117974, 24.90669839, 16.67581026,  6.36493079, 24.52678663,
#        19.60753083,  9.98176263, 21.57003641, 13.78283789, 13.36839823,
#        20.52890763, 17.95223857, 20.46896275,  7.1425216 , 10.42171041,
#         9.87705455,  7.52147127, 19.16555697,  9.97849299, 10.77215615,
#        17.0249779 ,  9.19948606, 18.36164218, 10.69788022,  5.42158542,
#        19.40508599, 15.9033723 , 19.29329736, 18.81586977, 10.29008546])

# %%
print("Slope is",model.coef_)
# Out:
# Slope is [ 0.05349116  0.11272667 -0.00131985]

# %%
list(zip(x,model.coef_))
# Out:
# [('TV', 0.05349115519765856),
#  ('Radio', 0.11272667197579378),
#  ('Newspaper', -0.0013198478715036727)]

# %%
print("intercept is",model.intercept_)
# Out:
# intercept is 4.709548719577212

# %%
from sklearn.metrics import r2_score
print("R2Score is ",r2_score(y_test,y_pred))
# Out:
# R2Score is  0.9045476537290444

# %%
from sklearn.metrics import mean_absolute_error
print("Error is",mean_absolute_error(y_test,y_pred))
# Out:
# Error is 1.338173951670126

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("Percentage error",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Percentage error 0.1764020216953907

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("Percentage error",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Percentage error 0.1764020216953907

# %%
import numpy as np
z=mean_squared_error(y_test,y_pred)
print(np.sqrt(z))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3112\4244011954.py in <module>
#       1 import numpy as np
# ----> 2 z=mean_squared_error(y_test,y_pred)
#       3 print(np.sqrt(z))
#
# NameError: name 'mean_squared_error' is not defined
